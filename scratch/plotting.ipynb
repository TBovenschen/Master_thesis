# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy 
import numpy as np
import xarray as xr
import math as m
from datetime import datetime
from datetime import timedelta
from glob import glob


output_NT = xr.open_dataset('/scratch/tycho/diff_model_NT.nc')
mean_ds_NT = xr.open_dataset('/scratch/tycho/diff_model_NT_mean.nc')
eig_val_NT = xr.open_dataset('/scratch/tycho/eig_val_NT.nc')
eig_vec_NT= xr.open_dataset('/scratch/tycho/eig_vec_NT.nc')

output = xr.open_dataset('/nethome/4276361/thesis/output/diff_model_WT.nc')
mean_ds = xr.open_dataset('/nethome/4276361/thesis/output/diff_model_WT_mean.nc')
eig_val = xr.open_dataset('/nethome/4276361/thesis/output/eig_val_WT.nc')
eig_vec= xr.open_dataset('/nethome/4276361/thesis/output/eig_vec_WT.nc')

# %%
# %matplotlib notebook


from plotting_functions import plot_ellipse
plot_ellipse(eig_val_NT, eig_vec_NT, scale=8000, title='Without tides')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
output = xr.open_dataset('/scratch/tycho/diff_model_NT.nc')


output.Age.max()
# Out:
# <xarray.DataArray 'Age' ()>
# array(1296600., dtype=float32)

# %%
# %matplotlib notebook


from plotting_functions import plot_ellipse
plot_ellipse(eig_val, eig_vec, scale=8000, title='With tides')
# Out:
# <img src="data:image/png;base64,..." width="974">

# %%
# %matplotlib notebook


from plotting_functions import plot_ellipse
plot_ellipse(eig_val_NT, eig_vec_NT, scale=8000, title='Without tides')
# Out:
# <img src="data:image/png;base64,..." width="912">
